# %%
dbutils.widgets.text("input_name","")

# %%
dbutils.fs

# %%
a = dbutils.widgets.get("input_name")

# %%
a = "Hammad  Zaki"

# %%
print(a)

# %%
# from tqdm import tqdm

# %%
# !pip install tqdm

# %%
print(a)

# %%
# Create first dropdown for database selection
dbutils.widgets.dropdown(
    name="database_name",
    defaultValue="sales_db",
    choices=["sales_db", "marketing_db", "finance_db"],
    label="Select Database"
)

# %%
data_size = 30

# %%
if data_size < 20:
    dbutils.notebook.run('filename.py')

# %%
print('I m here')

# %%
/raw-data/2025-11-11

# %%
df = spark.read.format("parquet").load("/FileStore/tables/2025-11-11")

# %%
import pandas as pd
